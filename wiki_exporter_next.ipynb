# %%
import pandas as pd
from indralib.indra_time import IndraTime
import re

# %%
# https://en.wikipedia.org/wiki/List_of_timelines

# %%
def remove_footnotes(text, numeric_only=True, single_letter_alpha=True):
    if numeric_only is False:
        text = re.sub(r"\[.*?\]", "", text)
    else:
        text = re.sub(r"\[\d+\]", "", text)
        if single_letter_alpha is True:
            text = re.sub(r"\[\w\]", "", text)
    return text

# %%
def extract_date_remarks(date):
    remarks = ""
    approxies = ["ca.", "c.", "circa", "fl.", "born", "died in", "Died", "died", "buried", "early", "or later", "later", "late", "mid", "or before", "before", 
                 "after", "around", "approximately", "~", ">", "<", "≈", "≥", "≤", "(?)", "?"]
    for ap in approxies:
        if ap in date:
            date = date.replace(ap, "").strip()
            if date != "":
                remarks = f"{ap}"
    if ' or ' in date:
        idx = date.find(' or ')
        remarks = date[idx+1:] 
        date = date[:idx]
    if date.endswith('s'):
        remarks = date
        date = date[:-1]
    if "±" in date:
        dates = date.split("±")
        date = dates[0].strip()
        append = dates[1].strip().split(" ")
        if len(append) > 1:
            date = date + " " + append[1]
            remarks = "±" + append[0]
        else:
            remark = "±" + dates[1].strip()
    date = date.replace("  ", " ")
    return date, remarks

# %%
def pre_clean(date):
    if isinstance(date, str):
        date = remove_footnotes(date)
        date = date.replace("–", " - ").replace("–", "-").replace("—", "-").replace(" ", " ").replace("\u2009", " ") \
                   .replace(" to ", " - ").replace(",", "").replace("\xa0", " ").replace("  ", " ") \
                   .replace("AD", "").replace("BCE", "BC").replace("  ", " ").replace(" mya", " ma bp").strip()
    return date

# %%
def decenturize(date):
    bc = False
    cent = False
    remarks = ""
    org_date = date
    postf = ['st', 'nd', 'rd', 'th']
    if ' century BC' in date:
        bc = True
        fpf = False
        for pf in postf:
            if pf in date:
                date = date.replace(pf, '')
                fpf = True
                break
        if fpf is True:
            date = date.replace(' century BC', '')
            cent = True
    elif ' century' in date:
        if 'c. ' in date:
            date = date.replace("c. ", "")
        fpf = False
        for pf in postf:
            if pf in date:
                date = date.replace(pf, '')
                fpf = True
                break
        if fpf is True:
            date = date.replace(' century', '')
            cent = True
    if cent is False:
        return org_date, remarks
    century = date.strip()
    try:
        int_cent = int(century)
    except:
        return org_date, remarks
    if bc is True:
        if int_cent == 1:
            date = f"100 BC - 1 BC"
        else:
            date = f"{int_cent}00 BC - {int_cent-1}00 BC"
    else:
        if int_cent == 1:
            date = "1 - 100"
        else:
            date = f"{int_cent-1}00 - {int_cent}00"
    return date, org_date

# %%
def check_date_parts(parts):
    for p in parts:
        for c in p:
            if c <'0' or c>'9':
                return False
    return True

# %%
def date_clean(date, default_scale = None):
    remarks = ""
    if isinstance(date, str):
        date = pre_clean(date)
        date_sub = date.split("-")
        if len(date_sub)==3 or (len(date_sub)==2 and " - " not in date and check_date_parts(date_sub)):
            return date, remarks
        if default_scale is not None:
            date = date.split("-")
            if len(date) == 1:
                date = date[0].strip()+f" {default_scale}"
            else:
                date = f"{date[0].strip()} {default_scale} - {date[1].strip()} {default_scale}"
        else:            
            dates = date.split(" - ")
            new_dates = []
            for di in dates:
                dj, rem = extract_date_remarks(di)
                if len(rem)>0:
                    if len(remarks) == 0:
                        remarks = rem
                    else:
                        remarks += f", {rem}"
                dj, rem = decenturize(dj)
                if len(rem)>0:
                    if len(remarks) == 0:
                        remarks = rem
                    else:
                        remarks += f", {rem}"
                if "/" in dj:
                    dj_parts = dj.split("/")
                    dj = dj_parts[0].strip()
                    alt_dj_stub = dj_parts[1].strip()
                    alt_dj = dj[:len(dj)-len(alt_dj_stub)] + alt_dj_stub
                    rem = f"Alt.: {alt_dj}"       
                    if len(remarks) == 0:
                        remarks = rem
                    else:
                        remarks += f", {rem}"
                new_dates.append(dj)
            date = " - ".join(new_dates)
            dates = date.split(" - ")
            if len(dates) == 2:
                sub_dates0 = dates[0].split(" ")
                sub_dates1 = dates[1].split(" ")
                if len(sub_dates0)==1 and len(sub_dates1)==2:
                    date = f"{sub_dates0[0]} {sub_dates1[1]} - {dates[1]}"
    else:
        if default_scale is not None:
            date = f"{date} {default_scale}"
        else:
            date = str(int(date))
    jd_dates = IndraTime.string_time_to_julian(date)
    
    if len(jd_dates) > 1 and jd_dates[1] is not None:
        date_start = IndraTime.julian_to_string_time(jd_dates[0])
        date_end = IndraTime.julian_to_string_time(jd_dates[1])
        date = f"{date_start} - {date_end}"
    else:
        date = IndraTime.julian_to_string_time(jd_dates[0])

    return date, remarks

# %%
def date_merge(year, rest):
    day = None
    month = None
    year = pre_clean(year)
    rest = rest.strip()
    year = year.strip()
    if rest is not None and len(rest) > 0:
        rparts = rest.split(" ")
        if len(rparts) == 1:
            month = rparts[0].strip().lower()
        else:
            try:
                month = rparts[1].strip().lower()
                day = int(rparts[0].strip())
            except ValueError:
                month = None
                day = None
            if month is None and day is None:
                try:
                    month = rparts[0].strip().lower()
                    day = int(rparts[1].strip())
                except ValueError:
                    month = None
                    day = None
    else:
        month = None
        day = None
    if month is not None:
        val_months = ["january", "february", "march", "april", "may", "june", "july", "august", "september", "october", "november", "december"]
        try:
            month_id = val_months.index(month) + 1
        except ValueError:
            month_id = None
            return f"{year}"
        year_parts = str(year).replace("\xa0"," ").split(" ", 1)
        if len(year_parts) > 1:
            year = year_parts[0]
            appendix = year_parts[1]
        else:
            appendix = ""
        if day is not None:
            date = f"{year}-{month_id:02d}-{day:02d}"
            if appendix != "":
                date = date + f" {appendix}"
        else:
            date = f"{year}-{month_id:02d}"
            if appendix != "":
                date = date + f" {appendix}"
        return date
    else:
        return f"{year}"

# %%
url= "https://de.wikipedia.org/wiki/Liste_homininer_Fossilien"
tables = pd.read_html(url)

# %%
tables[1]
# Out:
#                                       Abbildung  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4               OH 8 (Hand) bei talkorigins.org
# 5                                           NaN
# 6                             OH 62 bei msu.edu
# 7                     OH 65 bei talkorigins.org
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                   STW 53 bei talkorigins.org
# 13                                          NaN
# 14                    DNH 7 bei talkorigins.org
# 15                                          NaN
# 16                                          NaN
# 17                                          NaN
# 18                                          NaN
# 19                                          NaN
# 20                                          NaN
# 21                            OH 13 bei msu.edu
# 22                                          NaN
# 23                                          NaN
# 24  Peninj-Unterkiefer bei  anthropology.si.edu
# 25            Chellean OH 9 bei talkorigins.org
# 26                       KNM ER 992 bei msu.edu
# 27                                          NaN
# 28                                          NaN
# 29                                          NaN
# 30                                          NaN
# 31                                          NaN
#
#                                                  Name  \
# 0                                         KNM-ER 1813
# 1                                         KNM-ER 1470
# 2                                               SK 48
# 3   OH 5 „Zinj“ oder „Nussknackermensch“  (+ Unter...
# 4                                                OH 8
# 5                                    OH 24 („Twiggy“)
# 6                           OH 62 („Dik-dik hominid“)
# 7                                               OH 65
# 8                                              D 2700
# 9                                 OH 7 „Jonnys Child“
# 10                                        KNM-ER 3733
# 11                                        KNM-ER 1805
# 12                                             StW 53
# 13                                             SK 847
# 14                                   DNH 7 (Eurydice)
# 15                                              SK 46
# 16                                     OH 16 „George“
# 17                                         KNM-ER 406
# 18                                         KNM-ER 732
# 19                                       KNM-ER 23000
# 20                                         Sangiran 4
# 21                                      OH 13 „Cindy“
# 22                 KNM-WT 15000 („Nariokotome-Junge“)
# 23                                        KNM-ER 3883
# 24                     Peninj 1 oder  Peninj Mandible
# 25                              OH 9 („Chellean Man“)
# 26                                         KNM-ER 992
# 27                                         Sangiran 2
# 28                                         KGA 10-525
# 29                                             ATE7-1
# 30                                             ATE9-1
# 31                  Sangiran 17  Pithecanthropus VIII
#
#                           Alter  \
# 0                       1,9 mya
# 1                       1,9 mya
# 2                       1,8 mya
# 3                       1,8 mya
# 4                       1,8 mya
# 5                       1,8 mya
# 6                       1,8 mya
# 7                       1,8 mya
# 8                       1,8 mya
# 9                      1,75 mya
# 10                     1,75 mya
# 11                     1,74 mya
# 12                    2–1,5 mya
# 13                  1,8–1,5 mya
# 14                    2–1,5 mya
# 15                    2–1,5 mya
# 16                      1,7 mya
# 17                      1,7 mya
# 18                      1,7 mya
# 19                          NaN
# 20                      1,6 mya
# 21                      1,6 mya
# 22                      1,5 mya
# 23                  1,6–1,4 mya
# 24                      1,5 mya
# 25                      1,5 mya
# 26                      1,5 mya
# 27                  ca. 1,5 mya
# 28                      1,4 mya
# 29              ca. 1,4–1,1 mya
# 30                  ca. 1,2 mya
# 31  ca. 1,25 mya  (1,6–0,8 mya)
#
#                                                   Art  Jahr der Entdeckung  \
# 0                                        Homo habilis               1973.0
# 1                        Homo rudolfensis (Holotypus)               1972.0
# 2                               Paranthropus robustus               1948.0
# 3                     Paranthropus boisei (Holotypus)               1959.0
# 4                                        Homo habilis               1960.0
# 5                                        Homo habilis               1968.0
# 6                                        Homo habilis               1986.0
# 7                                        Homo habilis               1995.0
# 8                     Homo erectus ergaster georgicus               2001.0
# 9                            Homo habilis (Holotypus)               1960.0
# 10                       Homo erectus (H. ergaster ?)               1975.0
# 11                                       Homo habilis                  NaN
# 12                Homo habilis  („Homo gautengensis“)               1976.0
# 13  Homo erectus Homo ergaster ?  „Homo gautengensis“               1969.0
# 14                              Paranthropus robustus               1994.0
# 15                              Paranthropus robustus               1949.0
# 16                                       Homo habilis               1963.0
# 17                                Paranthropus boisei               1969.0
# 18                                Paranthropus boisei               1970.0
# 19                                                NaN                  NaN
# 20                                       Homo erectus               1939.0
# 21                                       Homo habilis               1963.0
# 22                       Homo erectus (H. ergaster ?)               1984.0
# 23                       Homo erectus (H. ergaster ?)                  NaN
# 24                                Paranthropus boisei               1964.0
# 25                                       Homo erectus               1960.0
# 26         Homo erectus (Holotypus von H. ergaster ?)               1971.0
# 27                                       Homo erectus               1937.0
# 28                                Paranthropus boisei               1993.0
# 29                                  Homo aff erectus.               2025.0
# 30                                           Homo sp.               2008.0
# 31                                       Homo erectus               1969.0
#
#                                     Fundort                 Erstbeschreibung
# 0                                     Kenia                     Kamoya Kimeu
# 1                                     Kenia                   Bernard Ngeneo
# 2                                 Südafrika                     Robert Broom
# 3                                  Tansania                      Mary Leakey
# 4                                  Tansania                  Jonathan Leakey
# 5                                  Tansania                      Peter Nzube
# 6                                  Tansania                        Tim White
# 7                                  Tansania                    Fidelis Masao
# 8                                  Georgien                              NaN
# 9                                  Tansania                  Jonathan Leakey
# 10                                    Kenia                   Bernard Ngeneo
# 11                        Koobi Fora, Kenia                              NaN
# 12                                Südafrika                     A. R. Hughes
# 13                                Südafrika                 Ronald J. Clarke
# 14                                Südafrika                     André Keyser
# 15                                Südafrika                     Robert Broom
# 16                                 Tansania                    Maiko Mutumbo
# 17                                    Kenia                   Richard Leakey
# 18                                    Kenia                   Richard Leakey
# 19                                      NaN                              NaN
# 20                                     Java        G.H.R. von Koenigswald[3]
# 21                                 Tansania                     Louis Leakey
# 22                                    Kenia                     Kamoya Kimeu
# 23                                    Kenia                   Richard Leakey
# 24                         Peninj, Tansania                     Kamoya Kimeu
# 25                                 Tansania                     Louis Leakey
# 26                                    Kenia                   Richard Leakey
# 27                                     Java           G.H.R. von Koenigswald
# 28                                Äthiopien                        A. Amzaye
# 29  Sierra de Atapuerca (Sima del Elefante)       Rosa Huguet et al. 2025[4]
# 30  Sierra de Atapuerca (Sima del Elefante)  Eduald Carbonell et al. 2008[5]
# 31                                     Java                   Herr Towikromo

# %%
hist = []
for table_index in range(5):
    print(f"Table {table_index}")
    for i, row in enumerate(tables[table_index].iterrows()):
        remarks = ""
        date_raw = row[1].iloc[2]
        if pd.isna(date_raw):
            continue
        date_raw = date_raw.replace(',', '.')
        date_inter = date_raw
        dps = date_raw.split(' ')
    
        if len(dps)>1 and dps[1] == 'mya':
            if '–' in dps[0]:
                dpsi = dps[0].split('–')
                date_inter = f"{dpsi[0]} mya - {dpsi[1]} " + ' '.join(dps[1:])
                
            
        # print(f"Date_raw: {date_raw}")
        if pd.isna(date_inter):
            continue
        date, remarks = date_clean(date_inter)
        print(f"cv d:{date}, r:{remarks}")
        name = row[1].iloc[1]
        if pd.isna(name):
            continue
        jd = IndraTime.string_time_to_julian(date)
        if len(jd) == 1:
            jd = (jd[0], jd[0])
        hist.append((jd, date, remarks, name))

entries = sorted(hist, key=lambda x: x[0])
for entry in entries:
    _, date, remarks, name = entry
    print(f"| {date} | {remarks} | {name} |")
# Out:
# Table 0
# cv d:7000.0 kya BP - 6000.0 kya BP, r:
# cv d:6000.0 kya BP, r:
# cv d:5500.0 kya BP - 5800.0 kya BP, r:
# cv d:4400.0 kya BP, r:
# cv d:4200.0 kya BP - 3800.0 kya BP, r:
# cv d:3600.0 kya BP, r:
# cv d:3800.0 kya BP - 3600.0 kya BP, r:
# cv d:3580.0 kya BP, r:
# cv d:3500.0 kya BP, r:
# cv d:3300.0 kya BP, r:(?)
# cv d:3300.0 kya BP, r:
# cv d:3200.0 kya BP - 3000.0 kya BP, r:
# cv d:3400.0 kya BP, r:
# cv d:3500.0 kya BP - 3000.0 kya BP, r:
# cv d:3200.0 kya BP, r:
# cv d:3200.0 kya BP, r:
# cv d:3000.0 kya BP, r:
# cv d:2800.0 kya BP - 2750.0 kya BP, r:
# cv d:2800.0 kya BP - 2600.0 kya BP, r:
# cv d:2500.0 kya BP, r:
# cv d:2500.0 kya BP, r:
# cv d:2500.0 kya BP, r:
# cv d:2500.0 kya BP, r:
# cv d:2400.0 kya BP, r:
# cv d:2400.0 kya BP, r:
# cv d:2300.0 kya BP, r:
# cv d:2160.0 kya BP - 2050.0 kya BP, r:
# cv d:2040.0 kya BP - 1950.0 kya BP, r:
# cv d:2000.0 kya BP, r:
# cv d:2000.0 kya BP, r:
# Table 1
# cv d:1900.0 kya BP, r:
# cv d:1900.0 kya BP, r:
# cv d:1800.0 kya BP, r:
# cv d:1800.0 kya BP, r:
# cv d:1800.0 kya BP, r:
# cv d:1800.0 kya BP, r:
# cv d:1800.0 kya BP, r:
# cv d:1800.0 kya BP, r:
# cv d:1800.0 kya BP, r:
# cv d:1750.0 kya BP, r:
# cv d:1750.0 kya BP, r:
# cv d:1740.0 kya BP, r:
# cv d:2000.0 kya BP - 1500.0 kya BP, r:
# cv d:1800.0 kya BP - 1500.0 kya BP, r:
# cv d:2000.0 kya BP - 1500.0 kya BP, r:
# cv d:2000.0 kya BP - 1500.0 kya BP, r:
# cv d:1700.0 kya BP, r:
# cv d:1700.0 kya BP, r:
# cv d:1700.0 kya BP, r:
# cv d:1600.0 kya BP, r:
# cv d:1600.0 kya BP, r:
# cv d:1500.0 kya BP, r:
# cv d:1600.0 kya BP - 1400.0 kya BP, r:
# cv d:1500.0 kya BP, r:
# cv d:1500.0 kya BP, r:
# cv d:1500.0 kya BP, r:
# cv d:1500.0 kya BP, r:ca.
# cv d:1400.0 kya BP, r:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Codeberg/EbookTools/.venv/lib/python3.13/site-packages/indralib/indra_time.py:452, in IndraTime.string_time_to_julian(time_str)
#     451 try:
# --> 452     year = int(dts[0])
#     453 except ValueError:
#
# ValueError: invalid literal for int() with base 10: '1.4'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 22
#      20 if pd.isna(date_inter):
#      21     continue
# ---> 22 date, remarks = date_clean(date_inter)
#      23 print(f"cv d:{date}, r:{remarks}")
#      24 name = row[1].iloc[1]
#
# Cell In[37], line 53, in date_clean(date, default_scale)
#      51     else:
#      52         date = str(int(date))
# ---> 53 jd_dates = IndraTime.string_time_to_julian(date)
#      55 if len(jd_dates) > 1 and jd_dates[1] is not None:
#      56     date_start = IndraTime.julian_to_string_time(jd_dates[0])
#
# File ~/Codeberg/EbookTools/.venv/lib/python3.13/site-packages/indralib/indra_time.py:454, in IndraTime.string_time_to_julian(time_str)
#     452         year = int(dts[0])
#     453     except ValueError:
# --> 454         raise ValueError(f"Invalid date format: {pt}")
#     455 elif len(dts) == 2:
#     456     # Year and month
#     457     try:
#
# ValueError: Invalid date format: 1.4

# %%
5,5–5,8 mya
# Out:
#   Cell In[43], line 1
#     5,5–5,8 mya
#        ^
# SyntaxError: invalid character '–' (U+2013)
